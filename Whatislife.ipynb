# %% [markdown]
# <a href="https://colab.research.google.com/github/b-to/Wintermute/blob/master/Whatislife.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##This is an example of a Workdcloud I created using Python.
# ##This is most beneficial for companies to find patterns and analyze feedback based on customer data.

# %%
# Start with loading all necessary libraries
import numpy as np
#Numpy provides ease of access to commonly used mathematical functions
import pandas as pd
#Pandas is used for easy indexing and data collection tools
from os import path
#Import the path resource from the operating system library
from PIL import Image
#Pillow is a good Python image library
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
#I am importing necessary packages for the word cloud

# %%
Wordclouddata = pd.read_csv("https://raw.githubusercontent.com/b-to/Wintermute/master/freeformResponses.csv")
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (5,17,21,38,50) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
Wordclouddata
# Out:
#       GenderFreeForm  ... JobSearchResourceFreeForm
# 0                NaN  ...                       NaN
# 1                NaN  ...                       NaN
# 2                NaN  ...                       NaN
# 3                NaN  ...                       NaN
# 4                NaN  ...                       NaN
# 5                NaN  ...                       NaN
# 6                NaN  ...                       NaN
# 7                NaN  ...                       NaN
# 8                NaN  ...                       NaN
# 9                NaN  ...                       NaN
# 10               NaN  ...                       NaN
# 11               NaN  ...                       NaN
# 12               NaN  ...                       NaN
# 13               NaN  ...                       NaN
# 14               NaN  ...                       NaN
# 15               NaN  ...                       NaN
# 16               NaN  ...                       NaN
# ...

# %%
Wordclouddata.shape
# Out:
# (16716, 62)

# %%
Wordclouddata.head()
# Out:
#   GenderFreeForm  ... JobSearchResourceFreeForm
# 0            NaN  ...                       NaN
# 1            NaN  ...                       NaN
# 2            NaN  ...                       NaN
# 3            NaN  ...                       NaN
# 4            NaN  ...                       NaN
#
# [5 rows x 62 columns]

# %%
# ?WordCloud

# %%
Wordclouddata2 = Wordclouddata[["MLToolNextYearFreeForm","WorkLibrariesFreeForm"]]

# %%
Wordclouddata2
# Out:
#       MLToolNextYearFreeForm                              WorkLibrariesFreeForm
# 0                        NaN                                                NaN
# 1                        NaN                                                NaN
# 2                        NaN                                                NaN
# 3                        NaN                                                NaN
# 4                        NaN                 python;scikit-learn; panda; numpy;
# 5                        NaN                                                NaN
# 6                        NaN                                                NaN
# 7                        NaN  Numpy, SciKit, Tensorflow, Keras, Watson Devel...
# 8                        NaN                                                NaN
# 9                    PyTorch                                                NaN
# 10                       NaN                                                NaN
# ...

# %%
wordcloud = WordCloud().generate(Wordclouddata2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-a2f714a22fc1> in <module>()
# ----> 1 wordcloud = WordCloud().generate(Wordclouddata2)
#
# /usr/local/lib/python3.6/dist-packages/wordcloud/wordcloud.py in generate(self, text)
#     603         self
#     604         """
# --> 605         return self.generate_from_text(text)
#     606
#     607     def _check_generated(self):
#
# /usr/local/lib/python3.6/dist-packages/wordcloud/wordcloud.py in generate_from_text(self, text)
#     584         self
#     585         """
# --> 586         words = self.process_text(text)
#     587         self.generate_from_frequencies(words)
#     588         return self
#
# /usr/local/lib/python3.6/dist-packages/wordcloud/wordcloud.py in process_text(self, text)
#     551         regexp = self.regexp if self.regexp is not None else r"\w[\w']+"
#     552
# ...
